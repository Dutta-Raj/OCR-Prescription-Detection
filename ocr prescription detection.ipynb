# %%
# -*- coding: utf-8 -*-
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, BatchNormalization, Dropout,
    Flatten, Dense, RepeatVector, Bidirectional, LSTM, TimeDistributed
)
from tensorflow.keras.callbacks import ModelCheckpoint, Callback
from tensorflow.keras.mixed_precision import set_global_policy
from google.colab import drive
from PIL import Image

# Enable mixed precision for speed
set_global_policy('mixed_float16')

# ---- Step 1: Mount and verify Google Drive ----
def mount_drive():
    drive.mount('/content/drive', force_remount=True)
    root_dir = '/content/drive/MyDrive/Classroom/New Data/data'
    if not os.path.isdir(root_dir):
        raise FileNotFoundError(f"Dataset root directory not found: {root_dir}")
    return root_dir

train_path = mount_drive()

# ---- Step 2: Parameters ----
n_chars = 'abcdefghijklmnopqrstuvwxyz '
char_to_idx = {c: i+1 for i, c in enumerate(n_chars)}  # 1-based
char_to_idx['<PAD>'] = 0
num_classes = len(char_to_idx)
seq_length = 10
input_shape = (32, 32, 1)
batch_size = 32

# ---- Step 3: Load and encode data ----
def load_data(root_dir):
    image_paths, labels = [], []
    for label in os.listdir(root_dir):
        subdir = os.path.join(root_dir, label)
        if not os.path.isdir(subdir):
            continue
        seq = [char_to_idx.get(ch, 0) for ch in label[:seq_length]]
        seq += [0] * (seq_length - len(seq))
        for fname in os.listdir(subdir):
            if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_paths.append(os.path.join(subdir, fname))
                labels.append(seq)
    return image_paths, np.array(labels, dtype=np.int32)

paths, labels = load_data(train_path)
if not paths:
    print(f"No images found in {train_path}. Generating a small temporary dataset...")
    temp_path = '/content/temp_dataset/training_words'
    os.makedirs(temp_path, exist_ok=True)
    for word in ['hello', 'world', 'test', 'data']:
        wd = os.path.join(temp_path, word)
        os.makedirs(wd, exist_ok=True)
        for i in range(3):
            img_arr = np.ones((32,32), dtype=np.uint8) * 255
            img_arr[i*8:(i+1)*8, :16] = 0
            Image.fromarray(img_arr).save(os.path.join(wd, f'{word}_{i}.png'))
    print(f"Using temporary dataset at {temp_path}")
    train_path = temp_path
    paths, labels = load_data(train_path)

# Split into train and validation sets
train_paths, val_paths, train_labels, val_labels = train_test_split(
    paths, labels, test_size=0.2, random_state=42
)

# ---- Step 4: Build tf.data pipelines ----
AUTOTUNE = tf.data.AUTOTUNE

def preprocess(path, label):
    image = tf.io.read_file(path)
    image = tf.image.decode_image(image, channels=1, expand_animations=False)
    image = tf.image.resize(image, [32, 32])
    image = tf.image.random_brightness(image, 0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.cast(image, tf.float32) / 255.0
    label = tf.one_hot(label, depth=num_classes)
    return image, label

train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_ds = train_ds.shuffle(len(train_paths))
train_ds = train_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(batch_size).prefetch(AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
val_ds = val_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.batch(batch_size).prefetch(AUTOTUNE)

# ---- Step 5: Define the model ----
def build_model():
    inp = Input(shape=input_shape, name='image')
    x = inp
    for filters in [32, 64, 128]:
        x = Conv2D(filters, (3, 3), padding='same', activation='relu')(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D((2, 2))(x)
        x = Dropout(0.3)(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = RepeatVector(seq_length)(x)
    x = Bidirectional(LSTM(128, return_sequences=True))(x)
    x = Dropout(0.5)(x)
    out = TimeDistributed(Dense(num_classes, activation='softmax', dtype='float32'))(x)

    model = Model(inputs=inp, outputs=out)
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

model = build_model()
model.summary()

# ---- Step 6: Callbacks ----
class PrintMetrics(Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"Epoch {epoch+1}: loss={logs['loss']:.4f}, acc={logs['accuracy']:.4f}, "
              f"val_loss={logs['val_loss']:.4f}, val_acc={logs['val_accuracy']:.4f}")

callbacks = [
    ModelCheckpoint('best_seq2seq_ocr.h5', monitor='val_loss', save_best_only=True),
    PrintMetrics()
]

# ---- Step 7: Train ----
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,  # Ensure this is set to 50
    callbacks=callbacks,
    verbose=1  # Set verbose to 1 to see the training output
)

# ---- Step 8: Evaluation ----
preds_list, true_list = [], []
for imgs, lbls in val_ds:
    preds = model.predict(imgs, verbose=0)
    preds_list.append(np.argmax(preds, axis=-1).flatten())
    true_list.append(np.argmax(lbls.numpy(), axis=-1).flatten())
preds_arr = np.concatenate(preds_list)
true_arr = np.concatenate(true_list)
char_acc = np.mean(preds_arr == true_arr)
f1 = f1_score(true_arr, preds_arr, average='weighted')
print(f"Character Accuracy: {char_acc:.4f}, F1 Score: {f1:.4f}")

# Confusion Matrix
cm = confusion_matrix(true_arr, preds_arr)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.show()

# ---- Step 9: Training Curves ----
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# No images found in /content/drive/MyDrive/Classroom/New Data/data. Generating a small temporary dataset...
# Using temporary dataset at /content/temp_dataset/training_words
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 32, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ cast_2 (Cast)                   │ (None, 32, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_2 (RepeatVector)  │ (None, 10, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 10, 256)        │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 10, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 10, 28)         │         7,196 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,019,548 (3.89 MB)
#  Trainable params: 1,019,100 (3.89 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.0222 - loss: 3.4166
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: loss=3.4166, acc=0.0222, val_loss=3.3653, val_acc=0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.0222 - loss: 3.4166 - val_accuracy: 0.0000e+00 - val_loss: 3.3653
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 986ms/step - accuracy: 0.0333 - loss: 3.6584
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: loss=3.6584, acc=0.0333, val_loss=3.2769, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0333 - loss: 3.6584 - val_accuracy: 0.5333 - val_loss: 3.2769
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1222 - loss: 3.1318
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: loss=3.1318, acc=0.1222, val_loss=3.1927, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1222 - loss: 3.1318 - val_accuracy: 0.5333 - val_loss: 3.1927
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2889 - loss: 2.6690
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: loss=2.6690, acc=0.2889, val_loss=3.1249, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2889 - loss: 2.6690 - val_accuracy: 0.5333 - val_loss: 3.1249
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5111 - loss: 2.4022
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: loss=2.4022, acc=0.5111, val_loss=3.0738, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5111 - loss: 2.4022 - val_accuracy: 0.5333 - val_loss: 3.0738
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 963ms/step - accuracy: 0.5444 - loss: 2.0831
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: loss=2.0831, acc=0.5444, val_loss=3.0323, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5444 - loss: 2.0831 - val_accuracy: 0.5333 - val_loss: 3.0323
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 953ms/step - accuracy: 0.5556 - loss: 2.2221Epoch 7: loss=2.2221, acc=0.5556, val_loss=3.1049, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 2.2221 - val_accuracy: 0.5333 - val_loss: 3.1049
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.5333 - loss: 2.2225Epoch 8: loss=2.2225, acc=0.5333, val_loss=3.1081, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5333 - loss: 2.2225 - val_accuracy: 0.5333 - val_loss: 3.1081
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5556 - loss: 2.1423Epoch 9: loss=2.1423, acc=0.5556, val_loss=3.1151, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5556 - loss: 2.1423 - val_accuracy: 0.5333 - val_loss: 3.1151
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5556 - loss: 2.1484Epoch 10: loss=2.1484, acc=0.5556, val_loss=3.1189, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5556 - loss: 2.1484 - val_accuracy: 0.5333 - val_loss: 3.1189
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 2.0395Epoch 11: loss=2.0395, acc=0.5556, val_loss=3.1372, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 2.0395 - val_accuracy: 0.5333 - val_loss: 3.1372
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.5556 - loss: 2.0259Epoch 12: loss=2.0259, acc=0.5556, val_loss=3.1453, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 2.0259 - val_accuracy: 0.5333 - val_loss: 3.1453
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.9888Epoch 13: loss=1.9888, acc=0.5556, val_loss=3.1268, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.9888 - val_accuracy: 0.5333 - val_loss: 3.1268
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.5444 - loss: 1.9916Epoch 14: loss=1.9916, acc=0.5444, val_loss=3.0831, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5444 - loss: 1.9916 - val_accuracy: 0.5333 - val_loss: 3.0831
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.5556 - loss: 1.9463
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15: loss=1.9463, acc=0.5556, val_loss=3.0227, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.9463 - val_accuracy: 0.5333 - val_loss: 3.0227
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5333 - loss: 2.0728
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 16: loss=2.0728, acc=0.5333, val_loss=2.9657, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5333 - loss: 2.0728 - val_accuracy: 0.5333 - val_loss: 2.9657
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 952ms/step - accuracy: 0.5444 - loss: 2.0151
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 17: loss=2.0151, acc=0.5444, val_loss=2.8844, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5444 - loss: 2.0151 - val_accuracy: 0.5333 - val_loss: 2.8844
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.5444 - loss: 1.9804
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 18: loss=1.9804, acc=0.5444, val_loss=2.7959, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5444 - loss: 1.9804 - val_accuracy: 0.5333 - val_loss: 2.7959
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.5556 - loss: 1.8130
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 19: loss=1.8130, acc=0.5556, val_loss=2.7123, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.8130 - val_accuracy: 0.5333 - val_loss: 2.7123
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.9936
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 20: loss=1.9936, acc=0.5556, val_loss=2.6406, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.9936 - val_accuracy: 0.5333 - val_loss: 2.6406
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5556 - loss: 1.8747
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 21: loss=1.8747, acc=0.5556, val_loss=2.5433, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5556 - loss: 1.8747 - val_accuracy: 0.5333 - val_loss: 2.5433
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 953ms/step - accuracy: 0.5333 - loss: 1.8597
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 22: loss=1.8597, acc=0.5333, val_loss=2.4497, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5333 - loss: 1.8597 - val_accuracy: 0.5333 - val_loss: 2.4497
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.8249
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 23: loss=1.8249, acc=0.5556, val_loss=2.3717, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.8249 - val_accuracy: 0.5333 - val_loss: 2.3717
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 936ms/step - accuracy: 0.5667 - loss: 1.7586
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 24: loss=1.7586, acc=0.5667, val_loss=2.2532, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5667 - loss: 1.7586 - val_accuracy: 0.5333 - val_loss: 2.2532
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.8900
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 25: loss=1.8900, acc=0.5556, val_loss=2.2202, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.8900 - val_accuracy: 0.5333 - val_loss: 2.2202
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 952ms/step - accuracy: 0.5667 - loss: 1.8075
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 26: loss=1.8075, acc=0.5667, val_loss=2.1522, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5667 - loss: 1.8075 - val_accuracy: 0.5333 - val_loss: 2.1522
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 947ms/step - accuracy: 0.5444 - loss: 1.7646
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 27: loss=1.7646, acc=0.5444, val_loss=2.0678, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5444 - loss: 1.7646 - val_accuracy: 0.5333 - val_loss: 2.0678
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.7427
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 28: loss=1.7427, acc=0.5556, val_loss=2.0312, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.7427 - val_accuracy: 0.5333 - val_loss: 2.0312
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 948ms/step - accuracy: 0.5667 - loss: 1.9223
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 29: loss=1.9223, acc=0.5667, val_loss=1.9732, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5667 - loss: 1.9223 - val_accuracy: 0.5333 - val_loss: 1.9732
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.8659
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 30: loss=1.8659, acc=0.5556, val_loss=1.9320, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.8659 - val_accuracy: 0.5333 - val_loss: 1.9320
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5556 - loss: 1.6726
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 31: loss=1.6726, acc=0.5556, val_loss=1.9162, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5556 - loss: 1.6726 - val_accuracy: 0.5333 - val_loss: 1.9162
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5444 - loss: 1.8450
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 32: loss=1.8450, acc=0.5444, val_loss=1.8802, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5444 - loss: 1.8450 - val_accuracy: 0.5333 - val_loss: 1.8802
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.5667 - loss: 1.7400
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 33: loss=1.7400, acc=0.5667, val_loss=1.8532, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5667 - loss: 1.7400 - val_accuracy: 0.5333 - val_loss: 1.8532
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.7482
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 34: loss=1.7482, acc=0.5556, val_loss=1.8312, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.7482 - val_accuracy: 0.5333 - val_loss: 1.8312
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.5222 - loss: 1.8288
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 35: loss=1.8288, acc=0.5222, val_loss=1.8187, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5222 - loss: 1.8288 - val_accuracy: 0.5333 - val_loss: 1.8187
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - accuracy: 0.5556 - loss: 1.7896
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 36: loss=1.7896, acc=0.5556, val_loss=1.8008, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.7896 - val_accuracy: 0.5333 - val_loss: 1.8008
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - accuracy: 0.5556 - loss: 1.8258
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 37: loss=1.8258, acc=0.5556, val_loss=1.7948, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.8258 - val_accuracy: 0.5333 - val_loss: 1.7948
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - accuracy: 0.5556 - loss: 1.7575
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 38: loss=1.7575, acc=0.5556, val_loss=1.7834, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.7575 - val_accuracy: 0.5333 - val_loss: 1.7834
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.6137
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 39: loss=1.6137, acc=0.5556, val_loss=1.7810, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.6137 - val_accuracy: 0.5333 - val_loss: 1.7810
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5444 - loss: 1.7594
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 40: loss=1.7594, acc=0.5444, val_loss=1.7755, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5444 - loss: 1.7594 - val_accuracy: 0.5333 - val_loss: 1.7755
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5556 - loss: 1.7053Epoch 41: loss=1.7053, acc=0.5556, val_loss=1.7756, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5556 - loss: 1.7053 - val_accuracy: 0.5333 - val_loss: 1.7756
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5444 - loss: 1.7726
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 42: loss=1.7726, acc=0.5444, val_loss=1.7741, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5444 - loss: 1.7726 - val_accuracy: 0.5333 - val_loss: 1.7741
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 964ms/step - accuracy: 0.5444 - loss: 1.6260Epoch 43: loss=1.6260, acc=0.5444, val_loss=1.7760, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5444 - loss: 1.6260 - val_accuracy: 0.5333 - val_loss: 1.7760
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - accuracy: 0.5556 - loss: 1.7057Epoch 44: loss=1.7057, acc=0.5556, val_loss=1.7783, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.7057 - val_accuracy: 0.5333 - val_loss: 1.7783
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5556 - loss: 1.7532Epoch 45: loss=1.7532, acc=0.5556, val_loss=1.7792, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.7532 - val_accuracy: 0.5333 - val_loss: 1.7792
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - accuracy: 0.5667 - loss: 1.6332Epoch 46: loss=1.6332, acc=0.5667, val_loss=1.7822, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5667 - loss: 1.6332 - val_accuracy: 0.5333 - val_loss: 1.7822
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.5556 - loss: 1.7167Epoch 47: loss=1.7167, acc=0.5556, val_loss=1.7871, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.7167 - val_accuracy: 0.5333 - val_loss: 1.7871
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 952ms/step - accuracy: 0.5556 - loss: 1.6529Epoch 48: loss=1.6529, acc=0.5556, val_loss=1.7923, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.6529 - val_accuracy: 0.5333 - val_loss: 1.7923
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5111 - loss: 1.7214Epoch 49: loss=1.7214, acc=0.5111, val_loss=1.7913, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5111 - loss: 1.7214 - val_accuracy: 0.5333 - val_loss: 1.7913
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5444 - loss: 1.7145Epoch 50: loss=1.7145, acc=0.5444, val_loss=1.7964, val_acc=0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5444 - loss: 1.7145 - val_accuracy: 0.5333 - val_loss: 1.7964
# Character Accuracy: 0.5333, F1 Score: 0.3710
